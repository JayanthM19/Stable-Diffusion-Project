# %%
evaluation_metrics = [
    "Image Quality",
    "Label Consistency",
    "Training Stability",
    "Generator Performance"
]

for metric in evaluation_metrics:
    print(metric)
# Out:
# Image Quality
# Label Consistency
# Training Stability
# Generator Performance

# %%
results = {
    "Image Quality": 8,
    "Label Consistency": 9,
    "Training Stability": 8,
    "Generator Performance": 8
}

for metric, score in results.items():
    print(metric, ":", score)
# Out:
# Image Quality : 8
# Label Consistency : 9
# Training Stability : 8
# Generator Performance : 8
