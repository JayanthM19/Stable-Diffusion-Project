# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
import torch

from task6_cgan.generator import Generator

from task6_cgan.discriminator import Discriminator

# %%
generator = Generator()

discriminator = Discriminator()

# %%
noise = torch.randn(
    8,
    100
)

labels = torch.randint(
    0,
    10,
    (8,)
)

# %%
fake_images = generator(
    noise,
    labels
)

print(fake_images.shape)
# Out:
# torch.Size([8, 1, 28, 28])

# %%
validity = discriminator(
    fake_images,
    labels
)

print(validity.shape)
# Out:
# torch.Size([8, 1])
